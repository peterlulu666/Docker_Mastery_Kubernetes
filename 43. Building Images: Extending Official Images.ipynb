# %%
# !docker container run -p 80:80 --rm nginx
# Out:
# Unable to find image 'nginx:latest' locally
# latest: Pulling from library/nginx
#
# fa5e3b41: Pulling fs layer
# 1cda007e: Pulling fs layer
# efba34d7: Pulling fs layer
# 26fb7aba: Pulling fs layer
# 3498bae6: Pulling fs layer
# Digest: sha256:e209ac2f37c70c1e0e9873a5f7231e91dcd83fdf1178d8ed36c2ec09974210ba[6A
# Status: Downloaded newer image for nginx:latest
# /docker-entrypoint.sh: /docker-entrypoint.d/ is not empty, will attempt to perform configuration
# /docker-entrypoint.sh: Looking for shell scripts in /docker-entrypoint.d/
# /docker-entrypoint.sh: Launching /docker-entrypoint.d/10-listen-on-ipv6-by-default.sh
# 10-listen-on-ipv6-by-default.sh: info: Getting the checksum of /etc/nginx/conf.d/default.conf
# 10-listen-on-ipv6-by-default.sh: info: Enabled listen on IPv6 in /etc/nginx/conf.d/default.conf
# /docker-entrypoint.sh: Launching /docker-entrypoint.d/20-envsubst-on-templates.sh
# /docker-entrypoint.sh: Launching /docker-entrypoint.d/30-tune-worker-processes.sh
# /docker-entrypoint.sh: Configuration complete; ready for start up
# 2022/11/26 17:58:38 [notice] 1#1: using the "epoll" event method
# 2022/11/26 17:58:38 [notice] 1#1: nginx/1.23.2
# 2022/11/26 17:58:38 [notice] 1#1: built by gcc 10.2.1 20210110 (Debian 10.2.1-6)
# 2022/11/26 17:58:38 [notice] 1#1: OS: Linux 5.15.0-47-generic
# 2022/11/26 17:58:38 [notice] 1#1: getrlimit(RLIMIT_NOFILE): 1048576:1048576
# 2022/11/26 17:58:38 [notice] 1#1: start worker processes
# 2022/11/26 17:58:38 [notice] 1#1: start worker process 47
# 2022/11/26 17:58:38 [notice] 1#1: start worker process 48
# 2022/11/26 17:58:38 [notice] 1#1: start worker process 49
# 2022/11/26 17:58:38 [notice] 1#1: start worker process 50
# 2022/11/26 17:58:38 [notice] 1#1: start worker process 51
# 2022/11/26 17:58:38 [notice] 1#1: start worker process 52
# 2022/11/26 17:58:38 [notice] 1#1: start worker process 53
# 2022/11/26 17:58:38 [notice] 1#1: start worker process 54
# 2022/11/26 17:58:38 [notice] 1#1: start worker process 55
# 2022/11/26 17:58:38 [notice] 1#1: start worker process 56
# 2022/11/26 17:58:38 [notice] 1#1: start worker process 57
# 2022/11/26 17:58:38 [notice] 1#1: start worker process 58
# 2022/11/26 17:58:38 [notice] 1#1: start worker process 59
# 2022/11/26 17:58:38 [notice] 1#1: start worker process 60
# 2022/11/26 17:58:38 [notice] 1#1: start worker process 61
# 2022/11/26 17:58:38 [notice] 1#1: start worker process 62
# 192.168.254.138 - - [26/Nov/2022:17:58:43 +0000] "GET / HTTP/1.1" 200 615 "https://peterlulu66-dockermaste-lrxarywhc0f.ws-us77.gitpod.io/" "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.13; rv:107.0) Gecko/20100101 Firefox/107.0" "64.189.206.192"
# 2022/11/26 17:58:44 [error] 47#47: *1 open() "/usr/share/nginx/html/favicon.ico" failed (2: No such file or directory), client: 192.168.254.138, server: localhost, request: "GET /favicon.ico HTTP/1.1", host: "80-peterlulu66-dockermaste-lrxarywhc0f.ws-us77.gitpod.io", referrer: "https://80-peterlulu66-dockermaste-lrxarywhc0f.ws-us77.gitpod.io/"
# 192.168.254.138 - - [26/Nov/2022:17:58:44 +0000] "GET /favicon.ico HTTP/1.1" 404 153 "https://80-peterlulu66-dockermaste-lrxarywhc0f.ws-us77.gitpod.io/" "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.13; rv:107.0) Gecko/20100101 Firefox/107.0" "64.189.206.192"
# ^C
# 2022/11/26 17:58:52 [notice] 1#1: signal 2 (SIGINT) received, exiting
# 2022/11/26 17:58:52 [notice] 47#47: exiting
# 2022/11/26 17:58:52 [notice] 48#48: exiting
# 2022/11/26 17:58:52 [notice] 49#49: exiting
# 2022/11/26 17:58:52 [notice] 48#48: exit
# 2022/11/26 17:58:52 [notice] 47#47: exit
# 2022/11/26 17:58:52 [notice] 50#50: exiting
# 2022/11/26 17:58:52 [notice] 49#49: exit
# 2022/11/26 17:58:52 [notice] 52#52: exiting
# 2022/11/26 17:58:52 [notice] 51#51: exiting
# 2022/11/26 17:58:52 [notice] 53#53: exiting
# 2022/11/26 17:58:52 [notice] 50#50: exit
# 2022/11/26 17:58:52 [notice] 54#54: exiting
# 2022/11/26 17:58:52 [notice] 51#51: exit
# 2022/11/26 17:58:52 [notice] 53#53: exit
# 2022/11/26 17:58:52 [notice] 52#52: exit
# 2022/11/26 17:58:52 [notice] 55#55: exiting
# 2022/11/26 17:58:52 [notice] 54#54: exit
# 2022/11/26 17:58:52 [notice] 57#57: exiting
# 2022/11/26 17:58:52 [notice] 55#55: exit
# 2022/11/26 17:58:52 [notice] 58#58: exiting
# 2022/11/26 17:58:52 [notice] 60#60: exiting
# 2022/11/26 17:58:52 [notice] 57#57: exit
# 2022/11/26 17:58:52 [notice] 58#58: exit
# 2022/11/26 17:58:52 [notice] 60#60: exit
# 2022/11/26 17:58:52 [notice] 59#59: exiting
# 2022/11/26 17:58:52 [notice] 59#59: exit
# 2022/11/26 17:58:52 [notice] 62#62: exiting
# 2022/11/26 17:58:52 [notice] 62#62: exit
# 2022/11/26 17:58:52 [notice] 56#56: exiting
# 2022/11/26 17:58:52 [notice] 56#56: exit
# 2022/11/26 17:58:52 [notice] 61#61: exiting
# 2022/11/26 17:58:52 [notice] 61#61: exit
# 2022/11/26 17:58:52 [notice] 1#1: signal 17 (SIGCHLD) received from 50
# 2022/11/26 17:58:52 [notice] 1#1: worker process 50 exited with code 0
# 2022/11/26 17:58:52 [notice] 1#1: signal 29 (SIGIO) received
# 2022/11/26 17:58:52 [notice] 1#1: signal 17 (SIGCHLD) received from 59
# 2022/11/26 17:58:52 [notice] 1#1: worker process 59 exited with code 0
# 2022/11/26 17:58:52 [notice] 1#1: signal 29 (SIGIO) received
# 2022/11/26 17:58:52 [notice] 1#1: signal 17 (SIGCHLD) received from 48
# 2022/11/26 17:58:52 [notice] 1#1: worker process 48 exited with code 0
# 2022/11/26 17:58:52 [notice] 1#1: worker process 49 exited with code 0
# 2022/11/26 17:58:52 [notice] 1#1: worker process 53 exited with code 0
# 2022/11/26 17:58:52 [notice] 1#1: worker process 54 exited with code 0
# 2022/11/26 17:58:52 [notice] 1#1: worker process 56 exited with code 0
# 2022/11/26 17:58:52 [notice] 1#1: worker process 58 exited with code 0
# 2022/11/26 17:58:52 [notice] 1#1: worker process 52 exited with code 0
# 2022/11/26 17:58:52 [notice] 1#1: worker process 61 exited with code 0
# 2022/11/26 17:58:52 [notice] 1#1: worker process 62 exited with code 0
# 2022/11/26 17:58:52 [notice] 1#1: worker process 47 exited with code 0
# 2022/11/26 17:58:52 [notice] 1#1: signal 29 (SIGIO) received
# 2022/11/26 17:58:52 [notice] 1#1: signal 17 (SIGCHLD) received from 61
# 2022/11/26 17:58:52 [notice] 1#1: signal 17 (SIGCHLD) received from 55
# 2022/11/26 17:58:52 [notice] 1#1: worker process 55 exited with code 0
# 2022/11/26 17:58:52 [notice] 1#1: signal 29 (SIGIO) received
# 2022/11/26 17:58:52 [notice] 1#1: signal 17 (SIGCHLD) received from 57
# 2022/11/26 17:58:52 [notice] 1#1: worker process 57 exited with code 0
# 2022/11/26 17:58:52 [notice] 1#1: worker process 51 exited with code 0
# 2022/11/26 17:58:52 [notice] 1#1: signal 29 (SIGIO) received
# 2022/11/26 17:58:52 [notice] 1#1: signal 17 (SIGCHLD) received from 51
# 2022/11/26 17:58:52 [notice] 1#1: signal 17 (SIGCHLD) received from 60
# 2022/11/26 17:58:52 [notice] 1#1: worker process 60 exited with code 0
# 2022/11/26 17:58:52 [notice] 1#1: exit

# %%
# !docker image build -t nginx-with-html .
# Out:
# Sending build context to Docker daemon  3.072kB
# Step 1/3 : FROM nginx:latest
#  ---> 88736fe82739
# Step 2/3 : WORKDIR /usr/share/nginx/html
#  ---> Running in 73af1d4615cb
# Removing intermediate container 73af1d4615cb
#  ---> 83c160cf3a55
# Step 3/3 : COPY index.html index.html
#  ---> 6094c1968713
# Successfully built 6094c1968713
# Successfully tagged nginx-with-html:latest

# %%
# !docker image ls -a
# Out:
# REPOSITORY                  TAG       IMAGE ID       CREATED          SIZE
# nginx-with-html             latest    6094c1968713   49 seconds ago   142MB
# <none>                      <none>    83c160cf3a55   51 seconds ago   142MB
# peterlulu666/a2c4fc540211   latest    a2c4fc540211   30 minutes ago   129MB
# nginx                       latest    88736fe82739   11 days ago      142MB
# debian                      jessie    3aaeab7a4777   20 months ago    129MB

# %%
# !docker container run -p 80:80 --rm nginx-with-html
# Out:
# /docker-entrypoint.sh: /docker-entrypoint.d/ is not empty, will attempt to perform configuration
# /docker-entrypoint.sh: Looking for shell scripts in /docker-entrypoint.d/
# /docker-entrypoint.sh: Launching /docker-entrypoint.d/10-listen-on-ipv6-by-default.sh
# 10-listen-on-ipv6-by-default.sh: info: Getting the checksum of /etc/nginx/conf.d/default.conf
# 10-listen-on-ipv6-by-default.sh: info: Enabled listen on IPv6 in /etc/nginx/conf.d/default.conf
# /docker-entrypoint.sh: Launching /docker-entrypoint.d/20-envsubst-on-templates.sh
# /docker-entrypoint.sh: Launching /docker-entrypoint.d/30-tune-worker-processes.sh
# /docker-entrypoint.sh: Configuration complete; ready for start up
# 2022/11/26 18:08:57 [notice] 1#1: using the "epoll" event method
# 2022/11/26 18:08:57 [notice] 1#1: nginx/1.23.2
# 2022/11/26 18:08:57 [notice] 1#1: built by gcc 10.2.1 20210110 (Debian 10.2.1-6)
# 2022/11/26 18:08:57 [notice] 1#1: OS: Linux 5.15.0-47-generic
# 2022/11/26 18:08:57 [notice] 1#1: getrlimit(RLIMIT_NOFILE): 1048576:1048576
# 2022/11/26 18:08:57 [notice] 1#1: start worker processes
# 2022/11/26 18:08:57 [notice] 1#1: start worker process 47
# 2022/11/26 18:08:57 [notice] 1#1: start worker process 48
# 2022/11/26 18:08:57 [notice] 1#1: start worker process 49
# 2022/11/26 18:08:57 [notice] 1#1: start worker process 50
# 2022/11/26 18:08:57 [notice] 1#1: start worker process 51
# 2022/11/26 18:08:57 [notice] 1#1: start worker process 52
# 2022/11/26 18:08:57 [notice] 1#1: start worker process 53
# 2022/11/26 18:08:57 [notice] 1#1: start worker process 54
# 2022/11/26 18:08:57 [notice] 1#1: start worker process 55
# 2022/11/26 18:08:57 [notice] 1#1: start worker process 56
# 2022/11/26 18:08:57 [notice] 1#1: start worker process 57
# 2022/11/26 18:08:57 [notice] 1#1: start worker process 58
# 2022/11/26 18:08:57 [notice] 1#1: start worker process 59
# 2022/11/26 18:08:57 [notice] 1#1: start worker process 60
# 2022/11/26 18:08:57 [notice] 1#1: start worker process 61
# 2022/11/26 18:08:57 [notice] 1#1: start worker process 62
# 192.168.254.138 - - [26/Nov/2022:18:09:29 +0000] "GET / HTTP/1.1" 200 184 "https://peterlulu66-dockermaste-lrxarywhc0f.ws-us77.gitpod.io/" "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.13; rv:107.0) Gecko/20100101 Firefox/107.0" "64.189.206.192"
# 192.168.254.138 - - [26/Nov/2022:18:09:31 +0000] "GET / HTTP/1.1" 304 0 "https://peterlulu66-dockermaste-lrxarywhc0f.ws-us77.gitpod.io/" "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.13; rv:107.0) Gecko/20100101 Firefox/107.0" "64.189.206.192"
# 192.168.254.138 - - [26/Nov/2022:18:09:32 +0000] "GET / HTTP/1.1" 304 0 "https://peterlulu66-dockermaste-lrxarywhc0f.ws-us77.gitpod.io/" "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.13; rv:107.0) Gecko/20100101 Firefox/107.0" "64.189.206.192"
# 192.168.254.138 - - [26/Nov/2022:18:09:32 +0000] "GET / HTTP/1.1" 304 0 "https://peterlulu66-dockermaste-lrxarywhc0f.ws-us77.gitpod.io/" "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.13; rv:107.0) Gecko/20100101 Firefox/107.0" "64.189.206.192"
# ^C
# 2022/11/26 18:09:42 [notice] 1#1: signal 2 (SIGINT) received, exiting
# 2022/11/26 18:09:42 [notice] 47#47: exiting
# 2022/11/26 18:09:42 [notice] 48#48: exiting
# 2022/11/26 18:09:42 [notice] 47#47: exit
# 2022/11/26 18:09:42 [notice] 49#49: exiting
# 2022/11/26 18:09:42 [notice] 50#50: exiting
# 2022/11/26 18:09:42 [notice] 48#48: exit
# 2022/11/26 18:09:42 [notice] 51#51: exiting
# 2022/11/26 18:09:42 [notice] 52#52: exiting
# 2022/11/26 18:09:42 [notice] 49#49: exit
# 2022/11/26 18:09:42 [notice] 53#53: exiting
# 2022/11/26 18:09:42 [notice] 50#50: exit
# 2022/11/26 18:09:42 [notice] 51#51: exit
# 2022/11/26 18:09:42 [notice] 54#54: exiting
# 2022/11/26 18:09:42 [notice] 52#52: exit
# 2022/11/26 18:09:42 [notice] 53#53: exit
# 2022/11/26 18:09:42 [notice] 55#55: exiting
# 2022/11/26 18:09:42 [notice] 54#54: exit
# 2022/11/26 18:09:42 [notice] 57#57: exiting
# 2022/11/26 18:09:42 [notice] 59#59: exiting
# 2022/11/26 18:09:42 [notice] 55#55: exit
# 2022/11/26 18:09:42 [notice] 57#57: exit
# 2022/11/26 18:09:42 [notice] 56#56: exiting
# 2022/11/26 18:09:42 [notice] 59#59: exit
# 2022/11/26 18:09:42 [notice] 56#56: exit
# 2022/11/26 18:09:42 [notice] 61#61: exiting
# 2022/11/26 18:09:42 [notice] 58#58: exiting
# 2022/11/26 18:09:42 [notice] 58#58: exit
# 2022/11/26 18:09:42 [notice] 61#61: exit
# 2022/11/26 18:09:42 [notice] 62#62: exiting
# 2022/11/26 18:09:42 [notice] 62#62: exit
# 2022/11/26 18:09:42 [notice] 60#60: exiting
# 2022/11/26 18:09:42 [notice] 60#60: exit
# 2022/11/26 18:09:42 [notice] 1#1: signal 17 (SIGCHLD) received from 51
# 2022/11/26 18:09:42 [notice] 1#1: worker process 51 exited with code 0
# 2022/11/26 18:09:42 [notice] 1#1: worker process 47 exited with code 0
# 2022/11/26 18:09:42 [notice] 1#1: worker process 52 exited with code 0
# 2022/11/26 18:09:42 [notice] 1#1: worker process 54 exited with code 0
# 2022/11/26 18:09:42 [notice] 1#1: worker process 55 exited with code 0
# 2022/11/26 18:09:42 [notice] 1#1: worker process 58 exited with code 0
# 2022/11/26 18:09:42 [notice] 1#1: worker process 59 exited with code 0
# 2022/11/26 18:09:42 [notice] 1#1: signal 29 (SIGIO) received
# 2022/11/26 18:09:42 [notice] 1#1: signal 17 (SIGCHLD) received from 58
# 2022/11/26 18:09:42 [notice] 1#1: signal 17 (SIGCHLD) received from 48
# 2022/11/26 18:09:42 [notice] 1#1: worker process 48 exited with code 0
# 2022/11/26 18:09:42 [notice] 1#1: signal 29 (SIGIO) received
# 2022/11/26 18:09:42 [notice] 1#1: signal 17 (SIGCHLD) received from 56
# 2022/11/26 18:09:42 [notice] 1#1: worker process 53 exited with code 0
# 2022/11/26 18:09:42 [notice] 1#1: worker process 49 exited with code 0
# 2022/11/26 18:09:42 [notice] 1#1: worker process 56 exited with code 0
# 2022/11/26 18:09:42 [notice] 1#1: worker process 57 exited with code 0
# 2022/11/26 18:09:42 [notice] 1#1: worker process 60 exited with code 0
# 2022/11/26 18:09:42 [notice] 1#1: worker process 61 exited with code 0
# 2022/11/26 18:09:42 [notice] 1#1: worker process 50 exited with code 0
# 2022/11/26 18:09:42 [notice] 1#1: worker process 62 exited with code 0
# 2022/11/26 18:09:42 [notice] 1#1: exit
